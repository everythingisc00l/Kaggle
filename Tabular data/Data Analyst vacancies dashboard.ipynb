# %% [markdown]
# # Data Analyst vacancies. Junior, Middle, Seniour salaries.
#
# Notebook for dataset **Data Analyst vacancies** https://www.kaggle.com/datasets/gennadiimanzhos/data-analyst-vacancies
#
# Scraped Jobs from HeadHunter in october 2023. Moscow city. No any augmentation or clearing data. Dataset include data analyst and other analyst's job positions.

# %%
import pandas as pd

# %%
df = pd.read_csv('Data Analyst Vacancies.csv')
df.head()
# Out:
#          id  premium                               name department  has_test  \
# 0  86571284    False  Data Scientist (стажер), удаленно        NaN     False
# 1  87273897    False                       Data Analyst        NaN     False
# 2  87271975    False                  Political analyst        NaN     False
# 3  86195321    False              Junior Data Scientist        NaN     False
# 4  87265216    False                              Юрист        NaN      True
#
#    response_letter_required  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
#                                                 area  \
# 0  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 1  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 2  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 3  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 4  {'id': '1', 'name': 'Москва', 'url': 'https://...
#
# ...

# %%
unique_data_analyst_moscow = df['experience'].apply(
    eval).apply(lambda x: x['name']).unique()
unique_data_analyst_moscow
# Out:
# array(['Нет опыта', 'От 3 до 6 лет', 'Более 6 лет', 'От 1 года до 3 лет'],
#       dtype=object)

# %% [markdown]
# Create new dataframe for each grade

# %% [markdown]
# 1. Junior (without experience)

# %%
no_experience_data_analyst_moscow = df[df['experience'].apply(
    eval).apply(lambda x: x['name']) == "Нет опыта"]
no_experience_data_analyst_moscow.head()
# Out:
#           id  premium                                name department  \
# 0   86571284    False   Data Scientist (стажер), удаленно        NaN
# 5   87156564    False  Стажер (информационные технологии)        NaN
# 9   86728622    False                 Junior data analyst        NaN
# 13  85002899    False                    Младший аналитик        NaN
# 17  87015620    False                       Data engineer        NaN
#
#     has_test  response_letter_required  \
# 0      False                     False
# 5      False                     False
# 9      False                     False
# 13      True                     False
# 17     False                     False
#
#                                                  area  \
# 0   {'id': '1', 'name': 'Москва', 'url': 'https://...
# 5   {'id': '1', 'name': 'Москва', 'url': 'https://...
# 9   {'id': '1', 'name': 'Москва', 'url': 'https://...
# 13  {'id': '1', 'name': 'Москва', 'url': 'https://...
# ...

# %% [markdown]
# 2. Middle

# %%
middle_data_analyst_moscow = df[df['experience'].apply(
    eval).apply(lambda x: x['name']) == "От 1 года до 3 лет"]
middle_data_analyst_moscow.head()
# Out:
#           id  premium                                        name  \
# 3   86195321    False                       Junior Data Scientist
# 4   87265216    False                                       Юрист
# 7   86742939    False                             Аналитик данных
# 10  86464709    False  Аналитик данных / Data scientist, удаленно
# 11  87300125    False                         Junior Data Analyst
#
#                                            department  has_test  \
# 3                                                 NaN     False
# 4                                                 NaN      True
# 7                                                 NaN     False
# 10  {'id': '816144-816144-office', 'name': 'ВкусВи...     False
# 11                                                NaN     False
#
#     response_letter_required  \
# 3                      False
# 4                      False
# 7                      False
# 10                     False
# ...

# %% [markdown]
# 3. Senior

# %%
senior_data_analyst_moscow = df[df['experience'].apply(
    eval).apply(lambda x: x['name']) == "От 3 до 6 лет"]
senior_data_analyst_moscow.head()
# Out:
#           id  premium                                         name department  \
# 1   87273897    False                                 Data Analyst        NaN
# 6   85948447    False   Ручной тестировщик ПО / QA manual (Remote)        NaN
# 16  86918159    False                             Ведущий аналитик        NaN
# 22  87283951    False                          Директор по сервису        NaN
# 25  85830928    False  Lead Data Analyst / Ведущий Аналитик Данных        NaN
#
#     has_test  response_letter_required  \
# 1      False                     False
# 6      False                     False
# 16     False                     False
# 22     False                     False
# 25     False                     False
#
#                                                  area  \
# 1   {'id': '1', 'name': 'Москва', 'url': 'https://...
# 6   {'id': '1', 'name': 'Москва', 'url': 'https://...
# 16  {'id': '1', 'name': 'Москва', 'url': 'https://...
# ...

# %% [markdown]
# ### Middle Data Analyst

# %% [markdown]
# 1. Junior

# %%
import numpy as np
salaries = no_experience_data_analyst_moscow.salary.dropna()
currencies = [ast.literal_eval(salaries.iloc[i])['currency']
              for i in range(len(salaries))]

rur = [ast.literal_eval(salaries.iloc[i]) for i in range(
    len(salaries)) if ast.literal_eval(salaries.iloc[i])['currency'] == 'RUR']

fr = [x['from'] for x in rur]
fr = list(filter(lambda x: x is not None, fr))

to = [x['to'] for x in rur]
to = list(filter(lambda x: x is not None, to))

salary_range = list(zip(fr, to))
av = map(np.mean, salary_range)
av = round(np.mean(list(av)), 1)

print("Middle salary of Junior Data Analyst in Moscow", av, "rubles")
# Out:
# Средняя зарплата Junior Data Analyst в Москве 78025.0 рублей

# %% [markdown]
# 2. Middle

# %%
import numpy as np
salaries = middle_data_analyst_moscow.salary.dropna()
currencies = [ast.literal_eval(salaries.iloc[i])['currency']
              for i in range(len(salaries))]

rur = [ast.literal_eval(salaries.iloc[i]) for i in range(
    len(salaries)) if ast.literal_eval(salaries.iloc[i])['currency'] == 'RUR']

fr = [x['from'] for x in rur]
fr = list(filter(lambda x: x is not None, fr))

to = [x['to'] for x in rur]
to = list(filter(lambda x: x is not None, to))

salary_range = list(zip(fr, to))
av = map(np.mean, salary_range)
av = round(np.mean(list(av)), 1)

print("Middle salary of Middle Data Analyst in Moscow", av, "rubles")
# Out:
# Средняя зарплата Middle Data Analyst в Москве 156000.0 рублей

# %% [markdown]
# 3. Senior

# %%
import numpy as np
salaries = senior_data_analyst_moscow.salary.dropna()
currencies = [ast.literal_eval(salaries.iloc[i])['currency']
              for i in range(len(salaries))]

rur = [ast.literal_eval(salaries.iloc[i]) for i in range(
    len(salaries)) if ast.literal_eval(salaries.iloc[i])['currency'] == 'RUR']

fr = [x['from'] for x in rur]
fr = list(filter(lambda x: x is not None, fr))

to = [x['to'] for x in rur]
to = list(filter(lambda x: x is not None, to))

salary_range = list(zip(fr, to))
av = map(np.mean, salary_range)
av = round(np.mean(list(av)), 1)

print("Middle salary of Senior Data Analyst in Moscow", av, "rubles")
# Out:
# Средняя зарплата Senior Data Analyst в Москве 243379.3 рублей

# %% [markdown]
# Top words in vacancies

# %%
import matplotlib.pylab as plt
from wordcloud import WordCloud, STOPWORDS
vacancy_names = Data_Analyst_Moscow.name
cloud = Counter(vacancy_names)
stopwords = set(STOPWORDS)
cloud = ''
for x in list(vacancy_names):
    cloud += x+' '
wordcloud = WordCloud(width=800, height=800,

                      stopwords=stopwords,
                      min_font_size=8, background_color='white'
                      ).generate(cloud)

plt.figure(figsize=(10, 10))
plt.imshow(wordcloud)
plt.savefig('vacancy_cloud.png')
